# %%
#from datetime import datetime
from sqlalchemy import create_engine, text
from sqlalchemy.engine import Engine

import pandas as pd
from datetime import datetime as dt

# %% [markdown]
# ## TODO - Uncomment the line for your userid to connect to your instance of the database

# %% [markdown]
# ### Create Engine for SQL

# %%
#sqlEngine =  create_engine("mysql+pymysql://admin_seshadhr:zmmnb378FHhHQP0ZMV858NA1L6bVgw7v3@mariadb/sakila?charset=utf8mb4")
#sqlEngine =  create_engine("mysql+pymysql://seshadhr:z7wmJj5q0pP3nsj3&u4nviws95@mariadb/sakila?charset=utf8mb4")  #sakila - common database
#sqlEngine =  create_engine("mysql+pymysql://seshadhr:z7wmJj5q0pP3nsj3&u4nviws95@mariadb/gaokj_db?charset=utf8mb4")  #gaokj_db database
#sqlEngine =  create_engine("mysql+pymysql://seshadhr:z7wmJj5q0pP3nsj3&u4nviws95@mariadb/wangesl_db?charset=utf8mb4")  #wangesl_db database
#sqlEngine =  create_engine("mysql+pymysql://seshadhr:z7wmJj5q0pP3nsj3&u4nviws95@mariadb/weiwm_db?charset=utf8mb4")  #weiwm_db database
#sqlEngine =  create_engine("mysql+pymysql://seshadhr:z7wmJj5q0pP3nsj3&u4nviws95@mariadb/wenzd_db?charset=utf8mb4")  #wenzd_db database
#sqlEngine =  create_engine("mysql+pymysql://seshadhr:z7wmJj5q0pP3nsj3&u4nviws95@mariadb/zhangdoc_db?charset=utf8mb4")  #zhangdoc_db database

# %%
# !pip install psycopg2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.3/384.3 kB 9.7 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [23 lines of output]
#       running egg_info
#       creating /private/var/folders/pw/qvyjd2q50ln1z88_kmphbfc00000gn/T/pip-pip-egg-info-1e4vy2qq/psycopg2.egg-info
#       writing /private/var/folders/pw/qvyjd2q50ln1z88_kmphbfc00000gn/T/pip-pip-egg-info-1e4vy2qq/psycopg2.egg-info/PKG-INFO
#       writing dependency_links to /private/var/folders/pw/qvyjd2q50ln1z88_kmphbfc00000gn/T/pip-pip-egg-info-1e4vy2qq/psycopg2.egg-info/dependency_links.txt
#       writing top-level names to /private/var/folders/pw/qvyjd2q50ln1z88_kmphbfc00000gn/T/pip-pip-egg-info-1e4vy2qq/psycopg2.egg-info/top_level.txt
# ...

# %%
# !pip install psycopg2-binary
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 23.3 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
sqlEngine = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5433/dvdrental')

# %%
sqlEngine
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost:5433/dvdrental)

# %% [markdown]
# ### get a SQL Connection

# %%
sqlConnection = sqlEngine.connect()

# %% [markdown]
# ### Select using SQL Engine and Pandas

# %%
aSQL = "select * from film"

# %%
df = None
df = pd.io.sql.read_sql(aSQL, con=sqlEngine)

# %%
df
# Out:
#      film_id              title  \
# 0        133    Chamber Italian
# 1        384   Grosse Wonderful
# 2          8    Airport Pollock
# 3         98  Bright Encounters
# 4          1   Academy Dinosaur
# ..       ...                ...
# 995      996     Young Language
# 996      997         Youth Kick
# 997      998       Zhivago Core
# 998      999  Zoolander Fiction
# 999     1000          Zorro Ark
#
#                                            description  release_year  \
# 0    A Fateful Reflection of a Moose And a Husband ...          2006
# 1    A Epic Drama of a Cat And a Explorer who must ...          2006
# 2    A Epic Tale of a Moose And a Girl who must Con...          2006
# 3    A Fateful Yarn of a Lumberjack And a Feminist ...          2006
# 4    A Epic Drama of a Feminist And a Mad Scientist...          2006
# ..                                                 ...           ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2006
# ...

# %%
dfFHP = pd.read_csv('framingham.csv')

# %%
dfFHP
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
tablename = 'FrmgHeartStudy'
dfFHP.to_sql(name=tablename,con=sqlEngine, if_exists='replace', index=False)
# Out:
# 240

# %% [markdown]
# ## TODO - Complete the SQL - By replace the code inside << XXXX >> below

# %%
bSQL = "select << column names >> from actor"

df = pd.io.sql.read_sql(bSQL, con=sqlEngine)
df
# Out:
#      actor_id first_name     last_name         last_update
# 0           1   PENELOPE       GUINESS 2006-02-15 04:34:33
# 1           2       NICK      WAHLBERG 2006-02-15 04:34:33
# 2           3         ED         CHASE 2006-02-15 04:34:33
# 3           4   JENNIFER         DAVIS 2006-02-15 04:34:33
# 4           5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33
# ..        ...        ...           ...                 ...
# 195       196       BELA        WALKEN 2006-02-15 04:34:33
# 196       197      REESE          WEST 2006-02-15 04:34:33
# 197       198       MARY        KEITEL 2006-02-15 04:34:33
# 198       199      JULIA       FAWCETT 2006-02-15 04:34:33
# 199       200      THORA        TEMPLE 2006-02-15 04:34:33
#
# [200 rows x 4 columns]

# %%
sql = '''SELECT <<Combine first and last name columns from the apporpriate tabe>> AS customer,
         address.phone, << title, film_id >>, rental.return_date, film.rental_duration
         FROM rental INNER JOIN customer ON rental.customer_id = customer.customer_id
         INNER JOIN address ON customer.address_id = address.address_id
         INNER JOIN inventory ON rental.inventory_id = inventory.inventory_id
         INNER JOIN film ON inventory.film_id = film.film_id
         WHERE rental.return_date IS NULL
         AND rental_date + INTERVAL film.rental_duration DAY < CURRENT_DATE()
         ORDER BY title
         LIMIT 5'''
df = pd.io.sql.read_sql(sql, con=sqlEngine)
df
# Out:
#                                             customer         phone  \
# 0  <<Combine first and last name columns from the...   62127829280
# 1  <<Combine first and last name columns from the...   99883471275
# 2  <<Combine first and last name columns from the...  272234298332
# 3  <<Combine first and last name columns from the...  864392582257
# 4  <<Combine first and last name columns from the...  371490777743
#
#    << title, film_id >> return_date  rental_duration
# 0  << title, film_id >>        None                6
# 1  << title, film_id >>        None                3
# 2  << title, film_id >>        None                5
# 3  << title, film_id >>        None                6
# 4  << title, film_id >>        None                4

# %% [markdown]
# ## TODO - Rent a DVD - Insert a record in Rental table

# %% [markdown]
# ### Insert using SQL ENGINE and Pandas
# df.to_sql(name=tablename,con=sqlengine, if_exists=append, index=writeindex, schema=schemaname)

# %% [markdown]
# INSERT INTO rental(rental_date, inventory_id, customer_id, staff_id)
#            VALUES(NOW(), 10, 3, 1);

# %% [markdown]
# ### Build you dataframe

# %%
#Old and going away
#dfRentCols = ['rental_date', 'inventory_id', 'customer_id', 'staff_id']
#dfRent = pd.DataFrame(columns = dfRentCols)
#dfRent = dfRent.append({'rental_date': dt.now(), 'inventory_id': 10, 'customer_id': 3, 'staff_id': 1}, ignore_index=True)

#
data = {'rental_date': [dt.now()], 'inventory_id': [10], 'customer_id': [3], 'staff_id': [1]}
dfRent = pd.DataFrame(data=data)
dfRent
# Out:
#                  rental_date  inventory_id  customer_id  staff_id
# 0 2022-10-16 18:15:54.973402            10            3         1

# %% [markdown]
# ### Save to SQL using SQL ENGINE & Pandas dataframe

# %%
tablename = 'rental'
dfRent.to_sql(name=tablename,con=sqlEngine, if_exists='append', index=False)
# Out:
# 1

# %%
cSQL = '''SELECT *
         FROM rental 
         WHERE customer_id = 3
         ORDER BY last_update DESC
         '''
df = pd.io.sql.read_sql(cSQL, con=sqlEngine)
df
# Out:
#     rental_id         rental_date  inventory_id  customer_id  \
# 0       16053 2022-10-16 18:15:54            10            3
# 1       16052 2022-10-16 18:13:19            10            3
# 2       16051 2022-10-16 17:30:50            10            3
# 3        9443 2005-07-30 21:45:46          1675            3
# 4        9595 2005-07-31 03:27:58          2829            3
# 5        9816 2005-07-31 11:32:58          4560            3
# 6       10597 2005-08-01 14:19:48          3292            3
# 7       12556 2005-08-18 14:49:55          1984            3
# 8       13403 2005-08-19 22:18:07          3241            3
# 9       13610 2005-08-20 06:14:12          2526            3
# 10      14699 2005-08-21 20:50:48          1427            3
# 11      15038 2005-08-22 09:37:27          1685            3
# 12      15619 2005-08-23 07:10:14          2468            3
# 13       9226 2005-07-30 13:31:20          4315            3
# ...

# %% [markdown]
# ### Update using SQL CONNECTION and SQL String
# #Update
# sqlconnection.execute(aSQL)

# %% [markdown]
# #Set your rental id from Insert

# %%
now = dt.strftime(dt.now(), '%Y-%m-%d %H:%M:%S')
uSQL = f'''UPDATE rental 
         << >> return_date = '{now}'
         WHERE rental_id = << rental id of Insert >>
         '''
uSQL
# Out:
# "UPDATE rental \n         SET return_date = '2022-10-16 18:15:55'\n         WHERE rental_id = 16050\n         "

# %%
sqlConnection.execute(uSQL)

# %% [markdown]
# ### Delete using SQL CONNECTION and SQL String
#
# #Delete
# sqlconnection.execute(aSQL)

# %%
dSQL = f'''DELETE FROM rental          
         WHERE rental_id = 16050
         '''
dSQL
# Out:
# 'DELETE FROM rental          \n         WHERE rental_id = 16050\n         '

# %%
sqlConnection.execute(dSQL)

# %%
df = pd.io.sql.read_sql(cSQL, con=sqlEngine)
df
# Out:
#     rental_id         rental_date  inventory_id  customer_id  \
# 0       16053 2022-10-16 18:15:54            10            3
# 1       16052 2022-10-16 18:13:19            10            3
# 2       16051 2022-10-16 17:30:50            10            3
# 3        9443 2005-07-30 21:45:46          1675            3
# 4        9595 2005-07-31 03:27:58          2829            3
# 5        9816 2005-07-31 11:32:58          4560            3
# 6       10597 2005-08-01 14:19:48          3292            3
# 7       12556 2005-08-18 14:49:55          1984            3
# 8       13403 2005-08-19 22:18:07          3241            3
# 9       13610 2005-08-20 06:14:12          2526            3
# 10      14699 2005-08-21 20:50:48          1427            3
# 11      15038 2005-08-22 09:37:27          1685            3
# 12      15619 2005-08-23 07:10:14          2468            3
# 13       9226 2005-07-30 13:31:20          4315            3
# ...

# %% [markdown]
# ## TODO - Create a New Table using Pandas

# %% [markdown]
# ### Create a new Table for Revenue using

# %%
'''SELECT i.store_id as Store, c.name as Category, f.rating as "Movie Rating", r.customer_id as customer
     , count(r.rental_id) as "Number of Rentals", sum(p.amount) as Revenue
FROM film f, payment p, inventory i, rental r, film_category fc, category c
WHERE p.rental_id = r.rental_id
AND r.inventory_id = i.inventory_id
AND i.film_id = f.film_id
AND f.film_id = fc.film_id
AND fc.category_id = c.category_id
GROUP BY 1, 2, 3, 4
ORDER BY 6 DESC;'''
# Out:
# 'SELECT i.store_id as Store, c.name as Category, f.rating as "Movie Rating", r.customer_id as customer\n     , count(r.rental_id) as "Number of Rentals", sum(p.amount) as Revenue\nFROM film f, payment p, inventory i, rental r, film_category fc, category c\nWHERE p.rental_id = r.rental_id\nAND r.inventory_id = i.inventory_id\nAND i.film_id = f.film_id\nAND f.film_id = fc.film_id\nAND fc.category_id = c.category_id\nGROUP BY 1, 2, 3, 4\nORDER BY 6 DESC;'
